# %% [markdown]
# #1.What is hypothesis testing in statistics?
# >Hypothesis testing is a statistical method that allows you to test assumptions (hypotheses) about a population parameter (like the mean or proportion) using sample data.
#
# #2.What is the null hypothesis, and how does it differ from the alternative hypothesis?
# >The null hypothesis (H₀) is a statement used in statistics that assumes there is no effect, no difference, or no relationship between variables. It represents the default or starting assumption that any observed differences in data are due to random chance. In contrast, the alternative hypothesis (H₁ or Ha) is what researchers aim to support; it suggests that there is an actual effect, difference, or relationship present. The main difference between the two is that the null hypothesis assumes the status quo or no change, while the alternative hypothesis reflects the claim that something significant or meaningful is occurring. In hypothesis testing, we collect data and analyze it to determine whether there is enough evidence to reject the null hypothesis in favor of the alternative. If the evidence is strong (e.g., the p-value is less than the significance level), we reject H₀ and accept H₁, indicating a statistically significant result.
#
# #3.What is the significance level in hypothesis testing, and why is it important?
# >The significance level (α) in hypothesis testing is the threshold for deciding whether to reject the null hypothesis, commonly set at 0.05. It represents the probability of making a Type I error — rejecting a true null hypothesis. A lower α means stricter criteria for claiming a significant result. It is important because it controls the risk of false positives in conclusions
#
# #4.What does a P-value represent in hypothesis testing?
# >A p-value in hypothesis testing represents the probability of obtaining results at least as extreme as the observed data, assuming the null hypothesis (H₀) is true. It helps determine the strength of evidence against H₀. A small p-value (typically ≤ 0.05) suggests strong evidence to reject H₀, while a large p-value indicates weak evidence, so we fail to reject H₀.
#
# #5.How do you interpret the P-value in hypothesis testing?
# >In hypothesis testing, the p-value helps you decide whether to reject the null hypothesis (H₀):
#
# >If p-value ≤ significance level (α) (e.g., 0.05):There is strong evidence against H₀, so you reject the null hypothesis.
#
# >If p-value > α:There is not enough evidence against H₀, so you fail to reject the null hypothesis.
#
# >The smaller the p-value, the stronger the evidence against H₀. It does not prove a hypothesis, but shows how likely your results are if H₀ were true.
#
# #6.What are Type 1 and Type 2 errors in hypothesis testing?
# >Type I Error (False Positive):
# This occurs when you reject the null hypothesis (H₀) even though it is actually true.
# It means detecting an effect that doesn't really exist.
# The probability of a Type I error is the significance level (α), commonly 0.05.
#
# >Type II Error (False Negative):
# This happens when you fail to reject the null hypothesis even though it is actually false.
# It means missing a real effect.
# The probability of a Type II error is denoted by β, and power = 1 − β measures the test’s ability to detect an effect.
#
# #7.What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
# >In hypothesis testing, the difference between a one-tailed and a two-tailed test lies in the direction of the hypothesis being tested. A one-tailed test is used when you want to determine whether a parameter is either greater than or less than a certain value, focusing on one direction only. For example, you might test whether a new drug increases recovery speed compared to the standard. In contrast, a two-tailed test checks for a difference in either direction, without specifying whether the parameter is higher or lower than the hypothesized value. This is used when any significant change is of interest, regardless of direction. The two-tailed test splits the significance level (α) between both ends of the distribution, while the one-tailed test places the entire α on one side.
#
# #8.What is the Z-test, and when is it used in hypothesis testing?
# >A Z-test is a statistical test used to determine whether there is a significant difference between sample and population means. It is used when the population variance is known and the sample size is large (typically n ≥ 30). The test statistic follows a standard normal distribution (Z-distribution). It is commonly used for testing means and proportions.
#
# #9.How do you calculate the Z-score, and what does it represent in hypothesis testing?
# - The Z-score is calculated by subtracting the population mean (μ) from the sample mean (x̄), then dividing by the standard error (σ/√n):
#
#
# The Z-score formula is:
#
# $$
# Z = \frac{\bar{x} - \mu}{\frac{\sigma}{\sqrt{n}}}
# $$
#
# where:
# - $\bar{x}$ = sample mean
# - $\mu$ = population mean
# - $\sigma$ = population standard deviation
# - $n$ = sample size
# - $\frac{\sigma}{\sqrt{n}}$ = standard error of the mean
#
#
#
#
# - It represents how many standard errors the sample mean is away from the population mean under the null hypothesis. In hypothesis testing, the Z-score helps determine how extreme the sample data is and whether to reject the null hypothesis.
#
# #10.What is the T-distribution, and when should it be used instead of the normal distribution?
# * The T-distribution is a probability distribution that is similar to the normal distribution but has heavier tails, meaning it is more spread out. It is used when the sample size is small (typically less than 30) and the population standard deviation is unknown. Unlike the normal distribution, the T-distribution accounts for extra uncertainty due to estimating the standard deviation from the sample. You should use the T-distribution instead of the normal distribution when working with small samples and unknown population variance to get more accurate confidence intervals and hypothesis tests.
#
# #11. What is the difference between a Z-test and a T-test?
# - The main difference between a Z-test and a T-test lies in the information you have about the population and the sample size:
#
# - A Z-test is used when the population standard deviation is known and the sample size is large (usually
# 𝑛
# ≥
# 30
# n≥30). It relies on the normal distribution (Z-distribution).
#
# - A T-test is used when the population standard deviation is unknown and the sample size is small (usually
# 𝑛
# <
# 30
# n<30).It uses the T-distribution ,which adjusts for extra uncertainty from estimating the standard deviation.
#
# #12.What is the T-test, and how is it used in hypothesis testing?
# - The T-test is a statistical test used to determine whether there is a significant difference between the means of two groups or between a sample mean and a population mean when the population standard deviation is unknown. It is especially useful for small sample sizes (typically less than 30). In hypothesis testing, the T-test helps decide whether to reject the null hypothesis by comparing the calculated T-statistic—based on sample data—to a critical value from the T-distribution, considering the chosen significance level. If the T-statistic falls into the rejection region, it indicates that the observed difference is unlikely due to chance, supporting the alternative hypothesis.
#
# #13. What is the relationship between Z-test and T-test in hypothesis testing?
# - The Z-test and T-test are closely related statistical tests used in hypothesis testing to compare means, but they differ mainly in how they handle population variability and sample size. The Z-test is used when the population standard deviation is known and the sample size is large, relying on the normal distribution. The T-test is used when the population standard deviation is unknown and the sample size is small, using the T-distribution which adjusts for the added uncertainty. As the sample size grows larger, the T-distribution approaches the normal distribution, so for large samples, the T-test and Z-test give very similar results. Essentially, the T-test can be seen as a generalization of the Z-test for situations with less information about population variability.
#
# #14.What is a confidence interval, and how is it used to interpret statistical results?
# - A confidence interval is a range of values, calculated from sample data, that is likely to contain the true population parameter (like the mean) with a certain level of confidence—commonly 95%. It provides an estimated range within which we expect the true value to lie, rather than giving a single point estimate. In interpreting statistical results, confidence intervals help show the precision and reliability of the estimate: a narrower interval means more precision, while a wider interval indicates more uncertainty. If a confidence interval for a difference between groups does not include zero, it suggests a statistically significant effect.
#
# #15.What is the margin of error, and how does it affect the confidence interval?
# - The margin of error is the amount added and subtracted from a sample estimate to create a confidence interval. It reflects the maximum expected difference between the sample statistic and the true population parameter due to sampling variability. A larger margin of error results in a wider confidence interval, indicating less precision, while a smaller margin of error produces a narrower interval, showing more precise estimates. Essentially, the margin of error controls the range of uncertainty around the estimate within the confidence interval.
#
# #16.How is Bayes' Theorem used in statistics, and what is its significance?
# - Bayes' Theorem is used in statistics to update the probability of a hypothesis based on new evidence or data. It combines prior knowledge (the prior probability) with the likelihood of observed data to calculate a revised probability (the posterior probability). This theorem is significant because it provides a formal way to incorporate new information and improve decision-making under uncertainty, making it fundamental in areas like medical diagnosis, machine learning, and risk assessment. In short, Bayes’ Theorem helps us update beliefs rationally as we gather more data.
#
# #17.What is the Chi-square distribution, and when is it used?
# - The Chi-square distribution is a probability distribution that describes the sum of the squares of independent standard normal random variables. It is a skewed distribution that depends on degrees of freedom, which usually relate to the number of variables or categories involved. The Chi-square distribution is commonly used in statistics for tests involving categorical data, such as the Chi-square test for independence (to check if two categorical variables are related) and the goodness-of-fit test (to see how well observed data fit an expected distribution). It’s especially useful when analyzing frequencies or counts in categories.
#
# #18.What is the Chi-square goodness of fit test, and how is it applied?
# -The Chi-square goodness of fit test is a statistical test used to determine whether an observed frequency distribution matches an expected distribution. It helps to check if the data fit a specific theoretical model or hypothesis. To apply the test, you:
#
# - Define the null hypothesis (H₀) stating that the observed data follow the expected distribution.
#
# - Calculate the expected frequencies for each category based on the hypothesized distribution.
#
# - Compute the Chi-square statistic by summing the squared differences between observed and expected frequencies, divided by the expected frequencies.
#
# - Compare the calculated Chi-square value to the critical value from the Chi-square distribution table with appropriate degrees of freedom.
#
# - If the statistic exceeds the critical value, reject H₀, indicating the observed data do not fit the expected distribution well.
#
# #19.What is the F-distribution, and when is it used in hypothesis testing?
# - The F-distribution is a probability distribution that arises when comparing the variances of two independent samples. It is positively skewed and depends on two sets of degrees of freedom—one for the numerator and one for the denominator. In hypothesis testing, the F-distribution is primarily used in ANOVA (Analysis of Variance) to test whether the means of three or more groups are equal by comparing their variances. It is also used in tests comparing two variances, such as the F-test. The F-distribution helps determine if observed differences between group variances are statistically significant or likely due to random chance.
#
# #20.What is an ANOVA test, and what are its assumptions?
# - ANOVA (Analysis of Variance) is a statistical test used to compare the means of three or more groups to determine if at least one group mean is significantly different from the others. Instead of comparing groups pairwise, ANOVA assesses overall differences by analyzing the variance within and between groups.
#
# #Key assumptions of ANOVA are:
#
# - Independence: Observations in each group must be independent of each other.
#
# - Normality: The data in each group should be approximately normally distributed.
#
# - Homogeneity of variances: The variances across groups should be roughly equal (also called homoscedasticity).
#
# #21.What are the different types of ANOVA tests?
# - One-Way ANOVA:
# Tests for differences among the means of three or more independent groups based on a single factor or independent variable.
#
# - Two-Way ANOVA:
# Examines the effect of two independent factors on a dependent variable, including any interaction between the factors.
#
# - Repeated Measures ANOVA:
# Used when the same subjects are measured multiple times under different conditions or over time.
#
# - MANOVA (Multivariate ANOVA):
# Extends ANOVA to test for differences in multiple dependent variables simultaneously across groups.
#
# #22.What is the F-test, and how does it relate to hypothesis testing?
# - The F-test is a statistical test that compares the variances of two or more groups to determine if they are significantly different. It calculates an F-statistic by dividing the variance between group means by the variance within the groups. In hypothesis testing, the F-test is commonly used in ANOVA to check if there are any significant differences among group means. A large F-statistic suggests that the group means are not all equal, leading to rejection of the null hypothesis that all group means are the same.

# %% [markdown]
# # **PRACTICAL** **QUESTIONS** **PART1**

# %%
#1.Write a Python program to generate a random variable and display its value.
import random
random_variable = random.random()
print(random_variable)
# Out:
# 0.49239754411604697

# %%
#2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint
low, high = 1, 10
dist = randint(low, high + 1)
x = np.arange(low, high + 1)
pmf_values = dist.pmf(x)
plt.stem(x, pmf_values)
plt.title('Discrete Uniform Distribution PMF')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.xticks(x)
plt.grid(True)
plt.show()

# %%
#3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution?
def bernoulli_pmf(x, p):
    if x not in [0, 1]:
        return 0
    return p**x * (1 - p)**(1 - x)

p = 0.3
print("P(X=1):", bernoulli_pmf(1, p))
print("P(X=0):", bernoulli_pmf(0, p))
# Out:
# P(X=1): 0.3
# P(X=0): 0.7

# %%
#4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram
import numpy as np
import matplotlib.pyplot as plt
n = 10
p = 0.5
size = 1000
data = np.random.binomial(n, p, size)

plt.hist(data, bins=np.arange(n+2) - 0.5, edgecolor='black')
plt.title('Binomial Distribution Histogram (n=10, p=0.5)')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(range(n+1))
plt.grid(axis='y')
plt.show()

# %%
#5. Create a Poisson distribution and visualize it using Python
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

lambda_ = 4
size = 1000

x = np.arange(0, 15)
pmf = poisson.pmf(x, lambda_)
plt.stem(x, pmf)
plt.title('Poisson Distribution PMF (λ = {})'.format(lambda_))
plt.xlabel('Number of events')
plt.ylabel('Probability')
plt.grid(True)
plt.show()

# %%
#6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution
import numpy as np
import matplotlib.pyplot as plt

low, high = 1, 10
values = np.arange(low, high + 1)
probability = 1 / (high - low + 1)
cdf = np.cumsum(np.full_like(values, probability, dtype=float))

plt.step(values, cdf, where='post')
plt.title('CDF of Discrete Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.xticks(values)
plt.ylim(0, 1.05)
plt.grid(True)
plt.show()

# %%
#7.Generate a continuous uniform distribution using NumPy and visualize it
import numpy as np
import matplotlib.pyplot as plt
samples = np.random.uniform(0, 1, 1000)

plt.hist(samples, bins=30, density=True, edgecolor='black', alpha=0.7)
plt.title('Continuous Uniform Distribution PDF')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
#8.Simulate data from a normal distribution and plot its histogram
import numpy as np
import matplotlib.pyplot as plt
mean = 0
std_dev = 1
sample_size = 1000
data = np.random.normal(mean, std_dev, sample_size)


plt.hist(data, bins=30, density=True, edgecolor='black', alpha=0.7)
plt.title('Histogram of Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
#9. Write a Python function to calculate Z-scores from a dataset and plot them
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_zscores(data):
    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data, ddof=1)
    z_scores = (data - mean) / std

    plt.scatter(range(len(z_scores)), z_scores, color='blue')
    plt.axhline(0, color='red', linestyle='--', label='Mean (Z=0)')
    plt.axhline(1, color='green', linestyle='--', label='Z=1')
    plt.axhline(-1, color='green', linestyle='--', label='Z=-1')
    plt.title('Z-scores of the Dataset')
    plt.xlabel('Index')
    plt.ylabel('Z-score')
    plt.legend()
    plt.grid(True)
    plt.show()

    return z_scores

sample_data = [10, 12, 23, 23, 16, 23, 21, 16]
zs = calculate_and_plot_zscores(sample_data)
print("Z-scores:", zs)
# Out:
# Z-scores: [-1.52752523 -1.14564392  0.95470327  0.95470327 -0.38188131  0.95470327
#   0.57282196 -0.38188131]

# %%
#10.Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

sample_size = 30
num_samples = 1000

sample_means = [np.mean(np.random.exponential(scale=1, size=sample_size)) for _ in range(num_samples)]

plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='blue')
mean = np.mean(sample_means)
std = np.std(sample_means)


plt.title('Central Limit Theorem Demonstration')
plt.xlabel('Sample mean')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# <ipython-input-23-a501f0633673>:19: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#11.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem
import numpy as np

import matplotlib.pyplot as plt
from scipy.stats import norm

mean = 50
std_dev = 10
sample_size = 30
num_samples = 1000

sample_means = [np.mean(np.random.normal(mean, std_dev, sample_size)) for _ in range(num_samples)]

plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='green')

mean_of_means = mean
std_of_means = std_dev / np.sqrt(sample_size)
x = np.linspace(min(sample_means), max(sample_means), 100)
plt.plot(x, norm.pdf(x, mean_of_means, std_of_means), 'r', label='Normal PDF')

plt.title('CLT Verification with Normal Distribution')
plt.xlabel('Sample mean')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
#12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x, 0, 1)

    plt.plot(x, y, label='Standard Normal PDF')
    plt.title('Standard Normal Distribution (mean=0, std=1)')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.show()

plot_standard_normal()

# %%
#13.Generate random variables and calculate their corresponding probabilities using the binomial distribution
import numpy as np
from scipy.stats import binom

n = 10
p = 0.5

x = np.arange(n + 1)
pmf = binom.pmf(x, n, p)

for outcome, prob in zip(x, pmf):
    print(f"Number of successes: {outcome}, Probability: {prob:.4f}")
# Out:
# Number of successes: 0, Probability: 0.0010
# Number of successes: 1, Probability: 0.0098
# Number of successes: 2, Probability: 0.0439
# Number of successes: 3, Probability: 0.1172
# Number of successes: 4, Probability: 0.2051
# Number of successes: 5, Probability: 0.2461
# Number of successes: 6, Probability: 0.2051
# Number of successes: 7, Probability: 0.1172
# Number of successes: 8, Probability: 0.0439
# Number of successes: 9, Probability: 0.0098
# Number of successes: 10, Probability: 0.0010

# %%
#14.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data_point, data):
    mean = np.mean(data)
    std = np.std(data, ddof=1)
    return (data_point - mean) / std

data = np.random.normal(50, 10, 1000)
data_point = 65
z = calculate_z_score(data_point, data)
print(f"Z-score of data point {data_point}: {z:.2f}")

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)

plt.plot(x, y, label='Standard Normal Distribution')
plt.axvline(z, color='red', linestyle='--', label=f'Z-score = {z:.2f}')
plt.title('Z-score on Standard Normal Distribution')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Z-score of data point 65: 1.57

# %%
#15. Implement hypothesis testing using Z-statistics for a sample dataset
import numpy as np
from scipy.stats import norm
sample = np.array([52, 55, 53, 58, 54, 57, 59, 56, 60, 54])
population_mean = 50
alpha = 0.05
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)
n = len(sample)

z_stat = (sample_mean - population_mean) / (sample_std / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print(f"Sample mean = {sample_mean:.2f}")
print(f"Z-statistic = {z_stat:.3f}")
print(f"P-value = {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis (H0).")
else:
    print("Fail to reject the null hypothesis (H0).")
# Out:
# Sample mean = 55.80
# Z-statistic = 6.900
# P-value = 0.0000
# Reject the null hypothesis (H0).

# %%
#16. Create a confidence interval for a dataset using Python and interpret the result
import numpy as np
from scipy import stats

data = np.array([52, 55, 53, 58, 54, 57, 59, 56, 60, 54])
confidence = 0.95

n = len(data)
mean = np.mean(data)
std_err = stats.sem(data)

margin = std_err * stats.t.ppf((1 + confidence) / 2, n - 1)
ci_lower = mean - margin
ci_upper = mean + margin

print(f"Sample Mean: {mean:.2f}")
print(f"{int(confidence*100)}% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean: 55.80
# 95% Confidence Interval: (53.90, 57.70)

# %%
#17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean
import numpy as np
from scipy import stats

data = np.random.normal(loc=100, scale=15, size=50)
confidence = 0.95

n = len(data)
mean = np.mean(data)
std_err = stats.sem(data)

margin = std_err * stats.t.ppf((1 + confidence) / 2, n - 1)
ci_lower = mean - margin
ci_upper = mean + margin

print(f"Sample Mean: {mean:.2f}")
print(f"{int(confidence*100)}% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean: 101.27
# 95% Confidence Interval: (97.11, 105.44)

# %%
#18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mean = 100
std_dev = 15

x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)
pdf = norm.pdf(x, mean, std_dev)

plt.plot(x, pdf, label='Normal PDF')
plt.title('Probability Density Function of Normal Distribution')
plt.xlabel('x')
plt.ylabel('Density')
plt.grid(True)
plt.legend()
plt.show()

# %%
#19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distributio
import numpy as np
from scipy.stats import poisson
import matplotlib.pyplot as plt

mu = 4
x = np.arange(0, 15)
cdf = poisson.cdf(x, mu)

for xi, cdf_val in zip(x, cdf):
    print(f"P(X ≤ {xi}) = {cdf_val:.4f}")

plt.step(x, cdf, where='post', label='Poisson CDF')
plt.title('Cumulative Distribution Function of Poisson Distribution')
plt.xlabel('x')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# P(X ≤ 0) = 0.0183
# P(X ≤ 1) = 0.0916
# P(X ≤ 2) = 0.2381
# P(X ≤ 3) = 0.4335
# P(X ≤ 4) = 0.6288
# P(X ≤ 5) = 0.7851
# P(X ≤ 6) = 0.8893
# P(X ≤ 7) = 0.9489
# P(X ≤ 8) = 0.9786
# P(X ≤ 9) = 0.9919
# P(X ≤ 10) = 0.9972
# P(X ≤ 11) = 0.9991
# P(X ≤ 12) = 0.9997
# P(X ≤ 13) = 0.9999
# P(X ≤ 14) = 1.0000

# %%
#20.Simulate a random variable using a continuous uniform distribution and calculate its expected value
import numpy as np

a = 10
b = 20

random_var = np.random.uniform(a, b)
expected_value = (a + b) / 2

print(f"Random Variable: {random_var:.2f}")
print(f"Expected Value: {expected_value:.2f}")
# Out:
# Random Variable: 15.85
# Expected Value: 15.00

# %%
#21.Write a Python program to compare the standard deviations of two datasets and visualize the difference.
import numpy as np
import matplotlib.pyplot as plt

data1 = np.random.normal(50, 5, 100)
data2 = np.random.normal(50, 15, 100)

std1 = np.std(data1, ddof=1)
std2 = np.std(data2, ddof=1)

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

plt.hist(data1, bins=20, alpha=0.6, label='Dataset 1 (σ≈5)')
plt.hist(data2, bins=20, alpha=0.6, label='Dataset 2 (σ≈15)')
plt.title('Comparison of Standard Deviations')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Standard Deviation of Dataset 1: 5.10
# Standard Deviation of Dataset 2: 15.03

# %%
#22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution
import numpy as np

data = np.random.normal(loc=100, scale=15, size=100)

data_range = np.max(data) - np.min(data)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

print(f"Range: {data_range:.2f}")
print(f"IQR: {iqr:.2f}")
# Out:
# Range: 63.61
# IQR: 13.77

# %%
#23. Implement Z-score normalization on a dataset and visualize its transformation
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

data = sns.load_dataset('tips')['total_bill']

z_scores = (data - data.mean()) / data.std()

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.hist(data, bins=15, color='skyblue', edgecolor='black')
plt.title('Original total_bill')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.hist(z_scores, bins=15, color='salmon', edgecolor='black')
plt.title('Z-score Normalized total_bill')
plt.xlabel('Z-score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
#24.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.
import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(data):
    return skew(data), kurtosis(data)

data = np.random.normal(0, 1, 1000)
skewness, kurt = calculate_skewness_kurtosis(data)

print(f"Skewness: {skewness:.4f}")
print(f"Kurtosis: {kurt:.4f}")
# Out:
# Skewness: 0.0955
# Kurtosis: -0.1165

# %% [markdown]
# # **PRACTICAL** **QUESTIONS** **PART2**

# %%
# 1.Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results
import numpy as np
from scipy.stats import norm

sample = np.array([52, 55, 53, 58, 54, 57, 59, 56, 60, 54])
pop_mean = 50
pop_std = 5
n = len(sample)
alpha = 0.05

sample_mean = np.mean(sample)
z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-statistic: {z_stat:.3f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: Sample mean is significantly different from population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference from population mean.")
# Out:
# Sample Mean: 55.80
# Z-statistic: 3.668
# P-value: 0.0002
# Reject the null hypothesis: Sample mean is significantly different from population mean.

# %%
# 2.Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python
import numpy as np
from scipy.stats import ttest_1samp

np.random.seed(42)
data = np.random.normal(loc=52, scale=5, size=30)
pop_mean = 50

t_stat, p_value = ttest_1samp(data, pop_mean)

print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject null hypothesis: Sample mean is significantly different from population mean.")
else:
    print("Fail to reject null hypothesis: No significant difference from population mean.")
# Out:
# T-statistic: 1.289
# P-value: 0.2075
# Fail to reject null hypothesis: No significant difference from population mean.

# %%
#3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.
import numpy as np
from scipy.stats import norm

sample = np.array([52, 55, 53, 58, 54, 57, 59, 56, 60, 54])
pop_mean = 50
pop_std = 5
n = len(sample)
alpha = 0.05

sample_mean = np.mean(sample)
z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-statistic: {z_stat:.3f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: Sample mean is significantly different from population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference from population mean.")
# Out:
# Sample Mean: 55.80
# Z-statistic: 3.668
# P-value: 0.0002
# Reject the null hypothesis: Sample mean is significantly different from population mean.

# %%
#4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

sample = np.array([52, 55, 53, 58, 54, 57, 59, 56, 60, 54])
pop_mean = 50
pop_std = 5
n = len(sample)
alpha = 0.05

sample_mean = np.mean(sample)
z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

z_critical = norm.ppf(1 - alpha/2)

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.plot(x, y, label='Standard Normal Distribution')
plt.fill_between(x, 0, y, where=(x <= -z_critical), color='red', alpha=0.3, label='Rejection Region')
plt.fill_between(x, 0, y, where=(x >= z_critical), color='red', alpha=0.3)
plt.axvline(z_stat, color='blue', linestyle='--', label=f'Z-statistic = {z_stat:.2f}')
plt.title('Two-tailed Z-test Decision Regions')
plt.xlabel('Z value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

print(f"Z-statistic: {z_stat:.3f}")
print(f"P-value: {p_value:.4f}")
if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Z-statistic: 3.668
# P-value: 0.0002
# Reject the null hypothesis.

# %%
#5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_type1_type2_errors(mu0=0, mu1=1.5, sigma=1, alpha=0.05):
    z_critical = norm.ppf(1 - alpha)
    beta = norm.cdf(z_critical - (mu1 - mu0)/sigma)

    x = np.linspace(mu0 - 4*sigma, mu1 + 4*sigma, 1000)
    h0 = norm.pdf(x, mu0, sigma)
    h1 = norm.pdf(x, mu1, sigma)

    plt.plot(x, h0, label='H0 Distribution (mean=mu0)')
    plt.plot(x, h1, label='H1 Distribution (mean=mu1)')

    plt.fill_between(x, 0, h0, where=(x > mu0 + z_critical*sigma), color='red', alpha=0.3, label='Type I Error (α)')
    plt.fill_between(x, 0, h1, where=(x <= mu0 + z_critical*sigma), color='blue', alpha=0.3, label='Type II Error (β)')

    plt.axvline(mu0 + z_critical*sigma, color='black', linestyle='--', label='Critical Value')
    plt.title('Type I and Type II Errors in Hypothesis Testing')
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f"Type I error (α): {alpha}")
    print(f"Type II error (β): {beta:.4f}")

plot_type1_type2_errors()
# Out:
# Type I error (α): 0.05
# Type II error (β): 0.5576

# %%
#6.Write a Python program to perform an independent T-test and interpret the results
import numpy as np
from scipy.stats import ttest_ind

group1 = np.array([20, 22, 19, 24, 20, 21, 23])
group2 = np.array([30, 28, 27, 35, 29, 31, 26])

t_stat, p_value = ttest_ind(group1, group2)

print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject null hypothesis: The groups have significantly different means.")
else:
    print("Fail to reject null hypothesis: No significant difference between group means.")
# Out:
# T-statistic: -6.170
# P-value: 0.0000
# Reject null hypothesis: The groups have significantly different means.

# %%
#7.Perform a paired sample T-test using Python and visualize the comparison results
import numpy as np
from scipy.stats import ttest_rel
import matplotlib.pyplot as plt

before = np.array([85, 88, 90, 86, 87, 89, 91])
after = np.array([88, 90, 92, 89, 90, 93, 94])

t_stat, p_value = ttest_rel(before, after)

plt.figure(figsize=(6,4))
plt.plot(range(len(before)), before, 'o-', label='Before')
plt.plot(range(len(after)), after, 's-', label='After')
plt.xticks(range(len(before)), [f'Sub {i+1}' for i in range(len(before))])
plt.ylabel('Score')
plt.title('Paired Sample Comparison')
plt.legend()
plt.grid(True)
plt.show()

print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject null hypothesis: Significant difference between before and after.")
else:
    print("Fail to reject null hypothesis: No significant difference between before and after.")
# Out:
# T-statistic: -10.954
# P-value: 0.0000
# Reject null hypothesis: Significant difference between before and after.

# %%
#8.Simulate data and perform both Z-test and T-test, then compare the results using Python
import numpy as np
from scipy.stats import ttest_1samp, norm

np.random.seed(0)
sample = np.random.normal(loc=52, scale=5, size=30)
pop_mean = 50
pop_std = 5
n = len(sample)
alpha = 0.05

sample_mean = np.mean(sample)

z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
z_p_value = 2 * (1 - norm.cdf(abs(z_stat)))

t_stat, t_p_value = ttest_1samp(sample, pop_mean)

print(f"Z-test: Z-stat = {z_stat:.3f}, P-value = {z_p_value:.4f}")
print(f"T-test: T-stat = {t_stat:.3f}, P-value = {t_p_value:.4f}")

if z_p_value < alpha:
    print("Z-test: Reject null hypothesis")
else:
    print("Z-test: Fail to reject null hypothesis")

if t_p_value < alpha:
    print("T-test: Reject null hypothesis")
else:
    print("T-test: Fail to reject null hypothesis")
# Out:
# Z-test: Z-stat = 4.617, P-value = 0.0000
# T-test: T-stat = 4.196, P-value = 0.0002
# Z-test: Reject null hypothesis
# T-test: Reject null hypothesis

# %%
#9. Write a Python function to calculate the confidence interval for a sample mean and explain its significanc
import numpy as np
from scipy.stats import t

def confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)
    t_crit = t.ppf((1 + confidence) / 2, df=n-1)
    margin = t_crit * std_err
    lower = mean - margin
    upper = mean + margin
    return lower, upper

data = [12, 15, 14, 16, 13, 14, 15, 17, 16, 14]
ci_lower, ci_upper = confidence_interval(data)

print(f"Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Confidence Interval: (13.52, 15.68)

# %%
#10.Write a Python program to calculate the margin of error for a given confidence level using sample data
import numpy as np
from scipy.stats import t

def margin_of_error(data, confidence=0.95):
    n = len(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)
    t_crit = t.ppf((1 + confidence) / 2, df=n-1)
    return t_crit * std_err

data = [12, 15, 14, 16, 13, 14, 15, 17, 16, 14]
me = margin_of_error(data)

print(f"Margin of Error: {me:.3f}")
# Out:
# Margin of Error: 1.077

# %%
#11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process
def bayes_theorem(prior_A, likelihood_B_given_A, prior_notA, likelihood_B_given_notA):
    numerator = prior_A * likelihood_B_given_A
    denominator = numerator + prior_notA * likelihood_B_given_notA
    posterior_A_given_B = numerator / denominator
    return posterior_A_given_B

prior_A = 0.01
prior_notA = 1 - prior_A
likelihood_B_given_A = 0.99
likelihood_B_given_notA = 0.05
posterior = bayes_theorem(prior_A, likelihood_B_given_A, prior_notA, likelihood_B_given_notA)
print(f"Posterior probability of disease given positive test: {posterior:.4f}")
# Out:
# Posterior probability of disease given positive test: 0.1667

# %%
#12. Perform a Chi-square test for independence between two categorical variables in PythoN
import numpy as np
from scipy.stats import chi2_contingency

data = np.array([[25, 15, 20],
                 [30, 10, 35]])

chi2, p, dof, expected = chi2_contingency(data)

print(f"Chi-square statistic: {chi2:.3f}")
print(f"P-value: {p:.4f}")
print(f"Degrees of freedom: {dof}")
print(expected)

if p < 0.05:
    print("Reject null hypothesis: Variables are dependent.")
else:
    print("Fail to reject null hypothesis: Variables are independent.")
# Out:
# Chi-square statistic: 3.927
# P-value: 0.1403
# Degrees of freedom: 2
# [[24.44444444 11.11111111 24.44444444]
#  [30.55555556 13.88888889 30.55555556]]
# Fail to reject null hypothesis: Variables are independent.

# %%
#13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.
import numpy as np

def expected_frequencies(observed):
    row_sums = observed.sum(axis=1, keepdims=True)
    col_sums = observed.sum(axis=0, keepdims=True)
    total = observed.sum()
    expected = row_sums @ col_sums / total
    return expected

observed = np.array([[30, 10, 20],
                     [20, 40, 30]])

expected = expected_frequencies(observed)
print(expected)
# Out:
# [[20. 20. 20.]
#  [30. 30. 30.]]

# %%
#14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.
import numpy as np
from scipy.stats import chisquare

observed = np.array([50, 30, 20])
expected = np.array([40, 40, 20])

chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print(f"Chi-square statistic: {chi2_stat:.3f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject null hypothesis: Observed data does not fit the expected distribution.")
else:
    print("Fail to reject null hypothesis: Observed data fits the expected distribution.")
# Out:
# Chi-square statistic: 5.000
# P-value: 0.0821
# Fail to reject null hypothesis: Observed data fits the expected distribution.
